# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('california_housing_test.csv',nrows=500)
df.head(500)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c0d5d336f207> in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 df=pd.read_csv('california_housing_test.csv',nrows=500)
#       5 df.head(500)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
x=df.total_rooms
plt.plot(x)

# %%
y=df.total_bedrooms
plt.bar(x,y)
# Out:
# <BarContainer object of 500 artists>

# %%
plt.hist(x)
# Out:
# (array([307., 147.,  36.,   4.,   2.,   1.,   1.,   0.,   1.,   1.]),
#  array([   67. ,  2472.4,  4877.8,  7283.2,  9688.6, 12094. , 14499.4,
#         16904.8, 19310.2, 21715.6, 24121. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd74fe71a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fd74e084e50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd74e0ca590>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd74e06c390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd74e0ba610>],
#  'means': []}

# %%
plt.pie(x,labels=y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-553f73ed515d> in <module>
# ----> 1 plt.pie(x,labels=y)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.scatter(x,y)
